# %% [markdown]
# Jhony, a 10th grade kid has recently started to learn python tkinter and is so much keen to understand how an MS Paint works and wants to create a very small replica of it in his own system using python with the following buttons
#
# pen
#
# brush
#
# color
#
# eraser
#
# brush/pen size changer
#
# import the libraries and create the GUI using the drawing features of the tkinter
